# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/python/Dataset/seattle-weather.csv")
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
new_df=df.drop(['date'],axis='columns')
new_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
x=new_df.drop('weather',axis='columns')
y=new_df['weather']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
x_train
# Out:
#       precipitation  temp_max  temp_min  wind
# 311             0.0      12.2       3.9   3.4
# 1419            0.0       8.3       0.6   4.0
# 804             8.1      16.7       4.4   3.0
# 1086            0.0      10.6       6.1   1.5
# 535             0.0      20.0      12.8   3.7
# ...             ...       ...       ...   ...
# 919             0.0      30.0      15.6   3.5
# 660             0.0      14.4       7.2   1.9
# 372             2.3      10.0       4.4   7.3
# 1158            0.0      12.8      -0.5   1.8
# 877             0.0      20.0      10.0   2.5
#
# [1168 rows x 4 columns]

# %%
x_test
# Out:
#       precipitation  temp_max  temp_min  wind
# 869             0.0      21.1      10.0   2.2
# 1303            0.0      23.3      12.2   1.9
# 144             0.0      17.2       8.9   3.3
# 1091            3.3       9.4       4.4   4.9
# 317             5.3      11.1       7.8   2.5
# ...             ...       ...       ...   ...
# 1069            3.0      12.8       6.7   3.1
# 978             0.0      27.8      13.9   6.5
# 132             0.0      24.4       6.7   3.4
# 1005            0.0      19.4      10.0   2.0
# 405             0.3       8.3       4.4   1.3
#
# [293 rows x 4 columns]

# %%
y_predicted=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.7986348122866894

# %%
y_predicted
# Out:
# array(['sun', 'sun', 'rain', 'rain', 'rain', 'sun', 'rain', 'fog', 'rain',
#        'sun', 'sun', 'sun', 'sun', 'snow', 'sun', 'rain', 'rain', 'rain',
#        'sun', 'sun', 'rain', 'rain', 'sun', 'rain', 'rain', 'rain',
#        'rain', 'sun', 'sun', 'sun', 'sun', 'rain', 'sun', 'rain', 'sun',
#        'sun', 'fog', 'rain', 'sun', 'rain', 'sun', 'rain', 'rain', 'rain',
#        'snow', 'sun', 'rain', 'rain', 'rain', 'snow', 'rain', 'rain',
#        'sun', 'sun', 'sun', 'sun', 'rain', 'sun', 'rain', 'rain', 'sun',
#        'rain', 'sun', 'sun', 'sun', 'sun', 'sun', 'rain', 'sun', 'sun',
#        'rain', 'rain', 'sun', 'sun', 'sun', 'sun', 'sun', 'sun', 'snow',
#        'sun', 'sun', 'rain', 'drizzle', 'sun', 'sun', 'sun', 'rain',
#        'rain', 'sun', 'rain', 'sun', 'fog', 'sun', 'sun', 'sun', 'sun',
#        'sun', 'rain', 'sun', 'rain', 'sun', 'sun', 'sun', 'sun', 'sun',
#        'sun', 'sun', 'sun', 'rain', 'sun', 'sun', 'sun', 'sun', 'sun',
# ...

# %%
a=float(input('Enter the precipitation : '))
b=float(input("Enter the maximum temperature: "))
c=float(input("Enter the minimum temperature : "))
d=float(input("Enter the wind rate : "))
df=pd.DataFrame([[a],[b],[c],[d]],dtype=int)
y_predicted=model.predict([[a,b,c,d]])
y_predicted
# Out:
# Enter the precipitation : 3
# Enter the maximum temperature: 4
# Enter the minimum temperature : 5
# Enter the wind rate : 6
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['rain'], dtype=object)
