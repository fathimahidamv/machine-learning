# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#svm
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
#RF
from sklearn.ensemble import RandomForestClassifier
#DT
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/drive/MyDrive/python/Dataset/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=df.drop('Outcome',axis='columns')
y=df['Outcome']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 708            9      164             78              0        0  32.8
# 34            10      122             78             31        0  27.6
# 377            1       87             60             37       75  37.2
# 220            0      177             60             29      478  34.6
# 458           10      148             84             48      237  37.6
# ..           ...      ...            ...            ...      ...   ...
# 728            2      175             88              0        0  22.9
# 370            3      173             82             48      465  38.4
# 590           11      111             84             40        0  46.8
# 394            4      158             78              0        0  32.9
# 123            5      132             80              0        0  26.8
#
#      DiabetesPedigreeFunction  Age
# 708                     0.148   45
# 34                      0.512   45
# ...

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 110            3      171             72             33      135  33.3
# 225            1       87             78             27       32  34.6
# 139            5      105             72             29      325  36.9
# 195            5      158             84             41      210  39.4
# 62             5       44             62              0        0  25.0
# ..           ...      ...            ...            ...      ...   ...
# 520            2       68             70             32       66  25.0
# 595            0      188             82             14      185  32.0
# 610            3      106             54             21      158  30.9
# 276            7      106             60             24        0  26.5
# 548            1      164             82             43       67  32.8
#
#      DiabetesPedigreeFunction  Age
# 110                     0.199   24
# 225                     0.101   22
# ...

# %%
#using DT

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predicted=model.predict(x_test)

# %%
print(type(x_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
model.score(x_test,y_test)
# Out:
# 0.6883116883116883

# %%
list=[]
a=float(input("Enter glucose level during pregnency: "))
b=float(input("Enter glucose level : "))
c=float(input("Enter BP : "))
d=float(input("Enter skin thickness : "))
e=float(input("Enter insulin : "))
f=float(input("Enter BMI: "))
g=float(input("Enter Diabates pedigree function: "))
h=float(input("Enter your age :"))
df=pd.DataFrame([[a],[b],[c],[d],[e],[f],[g],[h]],dtype=int)
y_predicted=model.predict([[a,b,c,d,e,f,g,h]])
#0	137	40	35	168	43.1	2.288	33	[1]

#1	93	70	31	0	30.4	0.315	23	[0]

i=y_predicted
list.append(i)
print(i)
# Out:
# Enter glucose level during pregnency: 0
# Enter glucose level : 137
# Enter BP : 40
# Enter skin thickness : 35
# Enter insulin : 168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-ed339f4ba3cb> in <cell line: 7>()
#       5 d=float(input("Enter skin thickness : "))
#       6 e=float(input("Enter insulin : "))
# ----> 7 f=float(input("Enter BMI: "))
#       8 g=float(input("Enter Diabates pedigree function: "))
#       9 h=float(input("Enter your age :"))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
#using RF

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)

# %%
y_predicted=model.predict(x_test)

# %%
model.score(x_test,y_test)

# %%
a=float(input("Enter glucose level during pregnency: "))
b=float(input("Enter glucose level : "))
c=float(input("Enter BP : "))
d=float(input("Enter skin thickness : "))
e=float(input("Enter insulin : "))
f=float(input("Enter BMI: "))
g=float(input("Enter Diabates pedigree function: "))
h=float(input("Enter your age :"))
df=pd.DataFrame([[a],[b],[c],[d],[e],[f],[g],[h]],dtype=int)
y_predicted=model.predict([[a,b,c,d,e,f,g,h]])
#0	137	40	35	168	43.1	2.288	33	[1]

#1	93	70	31	0	30.4	0.315	23	[0]
j=y_predicted
list.append(j)

print(j)

# %%
#using SVM

# %%
model=SVC()
model.fit(x_train,y_train)

# %%
y_predicted=model.predict(x_test)

# %%
model.score(x_test,y_test)

# %%
a=float(input("Enter glucose level during pregnency: "))
b=float(input("Enter glucose level : "))
c=float(input("Enter BP : "))
d=float(input("Enter skin thickness : "))
e=float(input("Enter insulin : "))
f=float(input("Enter BMI: "))
g=float(input("Enter Diabates pedigree function: "))
h=float(input("Enter your age :"))
df=pd.DataFrame([[a],[b],[c],[d],[e],[f],[g],[h]],dtype=int)
y_predicted=model.predict([[a,b,c,d,e,f,g,h]])
#0	137	40	35	168	43.1	2.288	33	[1]

#1	93	70	31	0	30.4	0.315	23	[0]
k=y_predicted
list.append(k)

print(k)

# %%
print(list)
if(list.count(1)<1):
  print("The person has Diabetes")
else:
  print("The person has no Diabetes")

# %%
#if(i==1 and j==1):
 # print("The person has diabetes")
#elif(i==1 and k==1):
 # print("The person has diabetes")
#elif(j==1 and k==1):
 # print("The person has diabetes")
#else:
 # print("The person has no diabetes")
